# %%
# 1. Install Ollama (zstd is required by the installer but missing from the base Colab image)
# !apt-get -qq update && apt-get -qq install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package zstd.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import os, subprocess, time

env = os.environ.copy()
env["OLLAMA_ORIGINS"] = "*"

subprocess.run(["bash", "-c", "fuser -k 11434/tcp || true"])
time.sleep(3)

ollama_process = subprocess.Popen(["ollama", "serve"], env=env)
time.sleep(5)
print("Ollama server starting (pid:", ollama_process.pid, ")")

status = subprocess.run(
    ["curl", "-s", "-o", "/dev/null", "-w", "%{http_code}", "http://localhost:11434/api/tags"],
    capture_output=True, text=True,
).stdout
print("Local check (expect 200):", status)
# Out:
# Ollama server starting (pid: 4308 )
# Local check (expect 200): 200

# %%
# 3. Pull the models used by CanvasUI (src/lib/models.ts)
# !ollama pull qwen2.5vl:7b
# !ollama pull qwen2.5-coder:14b

# %%
# !ollama pull qwen3.6:27b

# %%
# 4. Expose port 11434 publicly via ngrok
# !pip install -q pyngrok

from pyngrok import ngrok

NGROK_AUTHTOKEN = "3FREqxKHOq5kwY5G6BOzNHuINSI_7ddDirBNDFv6DMUkiaN35"
ngrok.set_auth_token(NGROK_AUTHTOKEN)

public_url = ngrok.connect(11434, host_header="localhost:11434")
print(public_url)
# Out:
# NgrokTunnel: "https://battle-lubricate-approval.ngrok-free.dev" -> "http://localhost:11434"

# %%
# !ollama list
# Out:
# NAME                 ID              SIZE      MODIFIED
# qwen3.6:27b          a50eda8ed977    17 GB     2 minutes ago
# qwen2.5-coder:14b    9ec8897f747e    9.0 GB    5 minutes ago
# qwen2.5vl:7b         5ced39dfa4ba    6.0 GB    7 minutes ago

# %%
print("abc")
# Out:
# abc

# %%
# !ollama run qwen3.6:27b "hi"
# Out:
# Thinking...
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user said "hi". This is a standard greeting
# greeting.
# 2.  **Identify Intent:** The user is initiating a conversation. No specific
# specific question or task is provided yet.
# 3.  **Determine Response Strategy:**
#    - Acknowledge the greeting warmly
#    - Keep it open-ended to encourage the user to share what they need
#    - Maintain a helpful and friendly tone
# 4.  **Draft Response (Internal):** "Hello! How can I assist you today?" or
# "Hi there! What's on your mind? I'm here to help with anything you need."
# 5.  **Refine Response:** Keep it concise, natural, and inviting. "Hi! How c
# can I help you today?" works well.
# 6.  **Final Output Generation:** Match the refined response.✅
# ...done thinking.
#
# Hi! How can I help you today? 😊
